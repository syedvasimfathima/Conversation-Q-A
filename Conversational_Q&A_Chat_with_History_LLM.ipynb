# %% [markdown]
# <a href="https://colab.research.google.com/github/syedvasimfathima/Conversation-Q-A/blob/main/Conversational_Q%26A_Chat_with_History_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-openai streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.4/557.4 kB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 104.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-protocol
#     Found existing installation: langchain-protocol 0.0.16
#     Uninstalling langchain-protocol-0.0.16:
#       Successfully uninstalled langchain-protocol-0.0.16
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.3
#     Uninstalling langchain-core-1.4.3:
#       Successfully uninstalled langchain-core-1.4.3
# ...

# %%
#Secured my API Key in Google colab
#api key is My_First_LLM (from OpenRouter)
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('API')

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

import streamlit as st

# %%
promt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a nice AI bot"),
        ("human", "{query}")
    ]
)
# This will now store ChatMessageHistory objects per session_id
chat_history = {}
print(chat_history)
# Out:
# {}

# %%
while True:
    query = input("Enter your query (type 'exit' to end): ")
    if query.lower() == 'exit':
        break
    llm = ChatOpenAI( model = "gpt-3.5-turbo", openai_api_key = os.environ.get("OPENAI_API_KEY"),base_url="https://openrouter.ai/api/v1")

    chain = promt | llm

    # Use the conversational_chain which manages history automatically
    response = chain.invoke(
        {"query": query},
        config={
            "configurable": {"session_id": "any_session_id"} # Use a consistent session_id for a single conversation
        }
    )

    print("AI: " + response.content)
# Out:
# Enter your query (type 'exit' to end): Hii
# AI: Hello! How can I assist you today?
# Enter your query (type 'exit' to end): I want to know what is apple
# AI: Apple is a type of fruit that grows on apple trees. It is a widely popular fruit known for its sweet taste and crisp texture. Apples are commonly eaten raw, but they can also be used in cooking and baking to make a variety of dishes such as pies, crisps, and sauces. There are many different varieties of apples, each with its own unique flavor and characteristics. They are a good source of fiber and vitamins, making them a healthy snack option. Apple is also the name of a major technology company known for its smartphones, computers, and other electronic devices.
# Enter your query (type 'exit' to end): exit
